# %%
import pandas as pd
import csv


df = pd.read_csv(
    "data/german_articles/test.csv",
    engine="python",
    sep=",",
    quoting=csv.QUOTE_NONE,   # don't treat " specially
    escapechar="\\",          # lets you keep commas by escaping them if needed
    on_bad_lines="warn",
    encoding="utf-8-sig"
)


df.head()
# Out:
# /var/folders/k_/559_7kh91xgfmdkgt0c3cb000000gn/T/ipykernel_67302/3046085024.py:5: ParserWarning: Skipping line 8: Expected 28 fields in line 8, saw 60
#
#   df = pd.read_csv(
# /var/folders/k_/559_7kh91xgfmdkgt0c3cb000000gn/T/ipykernel_67302/3046085024.py:5: ParserWarning: Skipping line 16: Expected 28 fields in line 16, saw 40
#
#   df = pd.read_csv(
# /var/folders/k_/559_7kh91xgfmdkgt0c3cb000000gn/T/ipykernel_67302/3046085024.py:5: ParserWarning: Skipping line 20: Expected 28 fields in line 20, saw 38
#
#   df = pd.read_csv(
# /var/folders/k_/559_7kh91xgfmdkgt0c3cb000000gn/T/ipykernel_67302/3046085024.py:5: ParserWarning: Skipping line 21: Expected 28 fields in line 21, saw 33
#
#   df = pd.read_csv(
# /var/folders/k_/559_7kh91xgfmdkgt0c3cb000000gn/T/ipykernel_67302/3046085024.py:5: ParserWarning: Skipping line 23: Expected 28 fields in line 23, saw 47
#
#   df = pd.read_csv(
# ...
